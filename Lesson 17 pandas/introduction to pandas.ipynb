# %%
# make a list of random numbers from 1 to 10, there should be 10 values in list

# %%
number = [2,6,1,3,4,7,5,8,9,10]

# %%
number2 = [12,432,34,234,123,45,6,284,87,546]

# %%
m = {}

# %%
# we are adding values to dictionary m

# %%
m['temperature1'] = number 
m['temperature2'] = number2

# %%
m
# Out:
# {'temperature1': [2, 6, 1, 3, 4, 7, 5, 8, 9, 10],
#  'temperature2': [12, 432, 34, 234, 123, 45, 6, 284, 87, 546]}

# %%
# make a tuple of 10 colors

# %%
colors = ("red","blue","orange","yellow","pink","purple","green","turqouis","light_blue","neon_green")

# %%
# add colors to dictionary m

# %%
m['c1'] = colors

# %%
m
# Out:
# {'temperature1': [2, 6, 1, 3, 4, 7, 5, 8, 9, 10],
#  'temperature2': [12, 432, 34, 234, 123, 45, 6, 284, 87, 546],
#  'c1': ('red',
#   'blue',
#   'orange',
#   'yellow',
#   'pink',
#   'purple',
#   'green',
#   'turqouis',
#   'light_blue',
#   'neon_green')}

# %%
print(m)
# Out:
# {'temperature1': [2, 6, 1, 3, 4, 7, 5, 8, 9, 10], 'temperature2': [12, 432, 34, 234, 123, 45, 6, 284, 87, 546], 'c1': ('red', 'blue', 'orange', 'yellow', 'pink', 'purple', 'green', 'turqouis', 'light_blue', 'neon_green')}

# %%
import pandas as pd

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %%
data = pd.DataFrame(m)

# %%
data['temperature1'] = data['temperature1'] * 100

# %%
data.plot()
# Out:
# <Axes: >

# %%
data.plot(kind="bar")
# Out:
# <Axes: >
